# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from itertools import combinations
from scipy.stats import ttest_ind

# %%
# %store -r w_0_labeled_radii

# %%
w_0_labeled_radii
# Out:
#             0 cell_type
# 0    2.085619       NaN
# 1    2.002284       NaN
# 2    1.893041       NaN
# 3    1.740061       NaN
# 4    2.039235       NaN
# ..        ...       ...
# 127  1.711997       RME
# 128  1.670875       RME
# 129  1.930774      SMDV
# 130  1.905029      SMDV
# 131  2.003724      SMDD
#
# [132 rows x 2 columns]

# %%
latency = {'ON': 20, 'OFF': 13, 'AVA': 66, 'RME': 72, 'SMDV': 60, 'SMDD': 33}

# %%
cell_types = ['ON', 'OFF', 'AVA', 'RME', 'SMDV', 'SMDD']

# Filter the DataFrame to include only the specified cell types
filtered_df = w_1_labeled_radii[w_1_labeled_radii['cell_type'].isin(cell_types)]

# Map the 'cell_type' column to the corresponding latency values
filtered_df['latency'] = filtered_df['cell_type'].map(latency)
# Out:
# /var/folders/4x/v6r504vx43l3xd43p7kmbr400000gn/T/ipykernel_94054/2698494517.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['latency'] = filtered_df['cell_type'].map(latency)

# %%
filtered_df
# Out:
#             0 cell_type  latency
# 103  3.177032        ON       20
# 104  3.154151        ON       20
# 105  3.215875        ON       20
# 106  3.132122        ON       20
# 107  3.153689        ON       20
# 108  3.101263        ON       20
# 109  3.155842       OFF       13
# 110  3.121312       OFF       13
# 111  3.236555       OFF       13
# 112  3.019702       OFF       13
# 113  3.137058       OFF       13
# 114  2.730136       AVA       66
# 115  2.726587       AVA       66
# 116  2.795342       AVA       66
# 117  2.803477       AVA       66
# 118  2.737234       AVA       66
# 119  2.753074       AVA       66
# 120  2.786067       AVA       66
# 121  2.818081       AVA       66
# 122  2.867095       RME       72
# 123  2.831438       RME       72
# 124  2.830723       RME       72
# 125  2.792197       RME       72
# 126  2.920720       RME       72
# 127  2.860016       RME       72
# 128  2.907249       RME       72
# 129  2.901213       RME       72
# ...

# %%
# Scatter plot: column '0' (x-axis) vs. latency (y-axis)
# Define the color mapping
color_discrete_map = {
    'ON': 'teal',
    'OFF': '#FF8C00',  # Dark orange
    'AVA': 'red',
    'RME': 'blue',
    'SMDV': 'purple',
    'SMDD': 'yellow'
}
colors = filtered_df['cell_type'].map(color_discrete_map)
plt.figure(figsize=(7, 5))
plt.scatter(filtered_df['latency'],filtered_df[0], c=colors, edgecolor='black', alpha=0.7)

# Labels and title
plt.xlabel('Latency', fontsize=14)
plt.ylabel('Radius', fontsize=14)
plt.title('Worm1: Latency vs. Radius', fontsize=16)

plt.show()

# %%
pearsonr(filtered_df['latency'], filtered_df[0])

# %%
# %store -r w_1_labeled_radii

# Define the color mapping
color_discrete_map = {
    'ON': 'teal',
    'OFF': '#FF8C00',  # Dark orange
    'AVA': 'red',
    'RME': 'blue',
    'SMDV': 'purple',
    'SMDD': 'yellow'
}
colors = filtered_df['cell_type'].map(color_discrete_map)
# Filter the DataFrame to include only the specified cell types
filtered_df = w_1_labeled_radii[w_1_labeled_radii['cell_type'].isin(cell_types)]

# Map the 'cell_type' column to the corresponding latency values
filtered_df['latency'] = filtered_df['cell_type'].map(latency)

# Scatter plot: column '0' (x-axis) vs. latency (y-axis)
plt.figure(figsize=(7, 5))
plt.scatter(filtered_df['latency'],filtered_df[0], c=colors, edgecolor='black', alpha=0.7)

# Labels and title
plt.xlabel('Latency', fontsize=14)
plt.ylabel('Radius', fontsize=14)
plt.title('Worm1: Latency vs. Radius', fontsize=16)

plt.show()
# Out:
# /var/folders/4x/v6r504vx43l3xd43p7kmbr400000gn/T/ipykernel_94054/4117219046.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['latency'] = filtered_df['cell_type'].map(latency)

# %%
# %store -r w_2_labeled_radii
# Filter the DataFrame to include only the specified cell types
filtered_df = w_2_labeled_radii[w_2_labeled_radii['cell_type'].isin(cell_types)]

# Define the color mapping
color_discrete_map = {
    'ON': 'teal',
    'OFF': '#FF8C00',  # Dark orange
    'AVA': 'red',
    'RME': 'blue',
    'SMDV': 'purple',
    'SMDD': 'yellow'
}
colors = filtered_df['cell_type'].map(color_discrete_map)
# Map the 'cell_type' column to the corresponding latency values
filtered_df['latency'] = filtered_df['cell_type'].map(latency)

# Scatter plot: column '0' (x-axis) vs. latency (y-axis)
plt.figure(figsize=(7, 5))
plt.scatter(filtered_df['latency'],filtered_df[0], c=colors, edgecolor='black', alpha=0.7)

# Labels and title
plt.xlabel('Latency', fontsize=14)
plt.ylabel('Radius', fontsize=14)
plt.title('Worm2: Latency vs. Radius', fontsize=16)

plt.show()
# Out:
# /var/folders/4x/v6r504vx43l3xd43p7kmbr400000gn/T/ipykernel_94054/759480601.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['latency'] = filtered_df['cell_type'].map(latency)

# %%
# %store -r w_3_labeled_radii
# Filter the DataFrame to include only the specified cell types
filtered_df = w_3_labeled_radii[w_3_labeled_radii['cell_type'].isin(cell_types)]

# Define the color mapping
color_discrete_map = {
    'ON': 'teal',
    'OFF': '#FF8C00',  # Dark orange
    'AVA': 'red',
    'RME': 'blue',
    'SMDV': 'purple',
    'SMDD': 'yellow'
}
colors = filtered_df['cell_type'].map(color_discrete_map)
# Map the 'cell_type' column to the corresponding latency values
filtered_df['latency'] = filtered_df['cell_type'].map(latency)

# Scatter plot: column '0' (x-axis) vs. latency (y-axis)
plt.figure(figsize=(7, 5))
plt.scatter(filtered_df['latency'],filtered_df[0], c=colors, edgecolor='black', alpha=0.7)

# Labels and title
plt.xlabel('Latency', fontsize=14)
plt.ylabel('Radius', fontsize=14)
plt.title('Worm1: Latency vs. Radius', fontsize=16)

plt.show()
# Out:
# /var/folders/4x/v6r504vx43l3xd43p7kmbr400000gn/T/ipykernel_94054/1620282719.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['latency'] = filtered_df['cell_type'].map(latency)

# %%
# %store -r w_4_labeled_radii
# Filter the DataFrame to include only the specified cell types
filtered_df = w_4_labeled_radii[w_4_labeled_radii['cell_type'].isin(cell_types)]

# Define the color mapping
color_discrete_map = {
    'ON': 'teal',
    'OFF': '#FF8C00',  # Dark orange
    'AVA': 'red',
    'RME': 'blue',
    'SMDV': 'purple',
    'SMDD': 'yellow'
}
colors = filtered_df['cell_type'].map(color_discrete_map)
# Map the 'cell_type' column to the corresponding latency values
filtered_df['latency'] = filtered_df['cell_type'].map(latency)

# Scatter plot: column '0' (x-axis) vs. latency (y-axis)
plt.figure(figsize=(7, 5))
plt.scatter(filtered_df['latency'],filtered_df[0], c=colors, edgecolor='black', alpha=0.7)

# Labels and title
plt.xlabel('Latency', fontsize=14)
plt.ylabel('Radius', fontsize=14)
plt.title('Worm1: Latency vs. Radius', fontsize=16)

plt.show()
# Out:
# /var/folders/4x/v6r504vx43l3xd43p7kmbr400000gn/T/ipykernel_94054/1962787397.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['latency'] = filtered_df['cell_type'].map(latency)

# %%
# Define the color mapping
color_discrete_map = {
    'ON': 'teal',
    'OFF': '#FF8C00',  # Dark orange
    'AVA': 'red',
    'RME': 'blue',
    'SMDV': 'purple',
    'SMDD': 'yellow'
}
colors = filtered_df['cell_type'].map(color_discrete_map)
filtered_df['latency'] = filtered_df['cell_type'].map(latency)

# Scatter plot: column '0' (x-axis) vs. latency (y-axis)
plt.figure(figsize=(7, 5))
plt.scatter(filtered_df['latency'],filtered_df[0], c=colors, edgecolor='black', alpha=0.7)

# Labels and title
plt.xlabel('Latency', fontsize=14)
plt.ylabel('Radius', fontsize=14)
plt.title('Worm1: Latency vs. Radius', fontsize=16)

plt.show()

# %%
# %store -r w_0_labeled_radii
# %store -r w_1_labeled_radii
# %store -r w_2_labeled_radii
# %store -r w_3_labeled_radii
# %store -r w_4_labeled_radii
# %store -r w_5_labeled_radii
# %store -r w_6_labeled_radii

# %%
# Filter the DataFrame to include only the specified cell types
filtered0_df = w_0_labeled_radii[w_0_labeled_radii['cell_type'].isin(cell_types)]
filtered1_df = w_1_labeled_radii[w_1_labeled_radii['cell_type'].isin(cell_types)]
filtered2_df = w_2_labeled_radii[w_2_labeled_radii['cell_type'].isin(cell_types)]
filtered3_df = w_3_labeled_radii[w_3_labeled_radii['cell_type'].isin(cell_types)]
filtered4_df = w_4_labeled_radii[w_4_labeled_radii['cell_type'].isin(cell_types)]
filtered5_df = w_5_labeled_radii[w_5_labeled_radii['cell_type'].isin(cell_types)]
filtered6_df = w_6_labeled_radii[w_6_labeled_radii['cell_type'].isin(cell_types)]

# %%
# Map the 'cell_type' column to the corresponding latency values
filtered0_df['latency'] = filtered0_df['cell_type'].map(latency)
filtered1_df['latency'] = filtered1_df['cell_type'].map(latency)
filtered2_df['latency'] = filtered2_df['cell_type'].map(latency)
filtered3_df['latency'] = filtered3_df['cell_type'].map(latency)
filtered4_df['latency'] = filtered4_df['cell_type'].map(latency)
filtered5_df['latency'] = filtered5_df['cell_type'].map(latency)
filtered6_df['latency'] = filtered6_df['cell_type'].map(latency)
# Out:
# /var/folders/4x/v6r504vx43l3xd43p7kmbr400000gn/T/ipykernel_94054/2082968666.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered0_df['latency'] = filtered0_df['cell_type'].map(latency)
# /var/folders/4x/v6r504vx43l3xd43p7kmbr400000gn/T/ipykernel_94054/2082968666.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered1_df['latency'] = filtered1_df['cell_type'].map(latency)
# ...

# %%
filtered0_df.shape
# Out:
# (29, 3)

# %%
combined = pd.concat([filtered0_df, filtered1_df, filtered2_df, filtered3_df, filtered4_df, filtered5_df, filtered6_df], axis = 0, ignore_index=True)

# %%
worm_0 = combined.iloc[: 29, :]

# %%
worm_id = (
    ['0'] * len(filtered0_df) +
    ['1'] * len(filtered1_df) +
    ['2'] * len(filtered2_df) +
    ['3'] * len(filtered3_df) +
    ['4'] * len(filtered4_df) +
    ['5'] * len(filtered5_df) +
    ['6'] * len(filtered6_df)
)

worm_id = np.array(worm_id)

# %%
combined['worm_id'] = worm_id

# %%
combined
# Out:
#             0 cell_type  latency worm_id
# 0    1.900446        ON       20       0
# 1    1.951433        ON       20       0
# 2    1.860834        ON       20       0
# 3    1.892517        ON       20       0
# 4    1.873417        ON       20       0
# ..        ...       ...      ...     ...
# 179  1.663927       RME       72       6
# 180  1.859762      SMDV       60       6
# 181  1.945893      SMDV       60       6
# 182  1.964453      SMDD       33       6
# 183  1.958567      SMDD       33       6
#
# [184 rows x 4 columns]

# %%
worm_0
# Out:
#            0 cell_type  latency  normalized_0  normalized_1
# 0   1.900446        ON       20      0.590958      0.572995
# 1   1.951433        ON       20      0.606813      0.588368
# 2   1.860834        ON       20      0.578640      0.561052
# 3   1.892517        ON       20      0.588492      0.570604
# 4   1.873417        ON       20      0.582553      0.564845
# 5   1.834733        ON       20      0.570524      0.553182
# 6   1.926396        ON       20      0.599027      0.580819
# 7   1.881384        ON       20      0.585030      0.567248
# 8   1.883743       OFF       13      0.582021      0.567959
# 9   1.892347       OFF       13      0.584679      0.570553
# 10  1.873388       OFF       13      0.578822      0.564837
# 11  1.919729       OFF       13      0.593140      0.578809
# 12  1.872686       OFF       13      0.578605      0.564625
# 13  1.897058       OFF       13      0.586135      0.571973
# 14  1.750054       OFF       13      0.540715      0.527651
# ...

# %%
color_discrete_map = {
    'ON': 'teal',
    'OFF': '#FF8C00',  # Dark orange
    'AVA': 'red',
    'RME': 'blue',
    'SMDV': 'purple',
    'SMDD': 'yellow'
}
colors = worm_0['cell_type'].map(color_discrete_map)


plt.figure(figsize=(7, 5))
plt.scatter(worm_0['latency'],worm_0[0], c=colors, edgecolor='black', alpha=0.7)
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=15, label=cell_type)
           for cell_type, color in color_discrete_map.items()]

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Latency (s)', fontsize=20)
# plt.legend(handles = handles, bbox_to_anchor=(1.05, 1), title='Cell Type', loc='upper left', fontsize=20, frameon=False)
plt.ylabel('Hyperbolic Radius', fontsize=20)
plt.title('All Stimulated Worms: Latency vs. Radius', fontsize=20)
# plt.savefig('/Users/iuliarusu/Documents/Sharpee/final_images/figure2/latency_v_radius.svg', format='svg', bbox_inches='tight')
plt.show()

# %%
#calculate the correlation coefficient
stats.pearsonr(combined['latency'], combined['normalized_1'])
# Out:
# PearsonRResult(statistic=-0.14227972803766806, pvalue=0.054024902011489774)

# %%
color_discrete_map = {
    'ON': 'teal',
    'OFF': '#FF8C00',  # Dark orange
    'AVA': 'red',
    'RME': 'blue',
    'SMDV': 'purple',
    'SMDD': 'yellow'
}
colors = combined['cell_type'].map(color_discrete_map)


plt.figure(figsize=(7, 5))
plt.scatter(combined['latency'],combined[0], c=colors, edgecolor='black', alpha=0.7)
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=15, label=cell_type)
           for cell_type, color in color_discrete_map.items()]

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Latency (s)', fontsize=20)
# plt.legend(handles = handles, bbox_to_anchor=(1.05, 1), title='Cell Type', loc='upper left', fontsize=20, frameon=False)
plt.ylabel('Hyperbolic Radius', fontsize=20)
plt.title('All Stimulated Worms: Latency vs. Radius', fontsize=20)
# plt.savefig('/Users/iuliarusu/Documents/Sharpee/final_images/figure2/latency_v_radius.svg', format='svg', bbox_inches='tight')
plt.show()

# %%
combined
# Out:
#     latency  normalized_by_worm cell_type
# 0        56            0.280935        ON
# 1        97            0.542696        ON
# 2        19            0.140924       RME
# 3        76            0.802197       AVA
# 4        65            0.074551      SMDD
# ..      ...                 ...       ...
# 95       86            0.728216       OFF
# 96       57            0.367783      SMDV
# 97       28            0.632306      SMDD
# 98       30            0.633530        ON
# 99       93            0.535775       RME
#
# [100 rows x 3 columns]

# %%
combined['normalized_0'] = combined.groupby('cell_type')[0].transform(lambda x: x / x.mean())


color_discrete_map = {
    'ON': 'teal',
    'OFF': '#FF8C00',  # Dark orange
    'AVA': 'red',
    'RME': 'blue',
    'SMDV': 'purple',
    'SMDD': 'yellow'
}

colors = combined['cell_type'].map(color_discrete_map)

plt.figure(figsize=(7, 5))
plt.scatter(combined['latency'], combined['normalized_0'], c=colors, edgecolor='black', alpha=0.7)


plt.xlabel('Latency', fontsize=14)
plt.ylabel('Normalized Radius', fontsize=14)
plt.title('All Worms: Latency vs. Normalized Radius', fontsize=16)

plt.show()

# %%
combined['normalized_1'] = combined[0].transform(lambda x: x / x.max())


color_discrete_map = {
    'ON': 'teal',
    'OFF': '#FF8C00',  # Dark orange
    'AVA': 'red',
    'RME': 'blue',
    'SMDV': 'purple',
    'SMDD': 'yellow'
}


colors = combined['cell_type'].map(color_discrete_map)


plt.figure(figsize=(7, 5))
plt.scatter(combined['latency'], combined['normalized_0'], c=colors, edgecolor='black', alpha=0.7)

plt.xlabel('Latency', fontsize=14)
plt.ylabel('Normalized Radius', fontsize=14)
plt.title('All Worms: Latency vs. Normalized Radius', fontsize=16)

plt.show()

# %%
combined['normalized_by_worm'] = combined[0] / combined.groupby('worm_id')[0].transform('mean')

# %%
color_discrete_map = {
    'ON': 'teal',
    'OFF': '#FF8C00',  # Dark orange
    'AVA': 'red',
    'RME': 'blue',
    'SMDV': 'purple',
    'SMDD': 'yellow'
}


colors = combined['cell_type'].map(color_discrete_map)


plt.figure(figsize=(7, 5))
plt.scatter(combined['latency'], combined['normalized_by_worm'], c=colors, edgecolor='black', alpha=0.7)

plt.xlabel('Latency', fontsize=14)
plt.ylabel('Normalized Radius', fontsize=14)
plt.title('All Worms: Latency vs. Normalized Radius', fontsize=16)

plt.show()

# %%
# Extract relevant data
x = combined['latency']
y = combined['normalized_by_worm']

# Define color mapping
colors = combined['cell_type'].map(color_discrete_map)

# Compute Pearson correlation coefficient and linear regression line
corr_coef, p_value = stats.pearsonr(x, y)
slope, intercept, _, _, _ = stats.linregress(x, y)

# Generate regression line
x_vals = np.linspace(x.min(), x.max(), 100)  # Regression line over real data range
y_vals = slope * x_vals + intercept

# Create figure
plt.figure(figsize=(7, 5))

# Scatter plot
plt.scatter(x, y, c=colors, edgecolor='black', alpha=0.7, s= 90)
plt.tick_params(axis='both', which='major', labelsize=15)
# Plot regression line
plt.plot(x_vals, y_vals, color='grey', linestyle='dashed', linewidth=2, label=f"Pearson r = {corr_coef:.2f}")

# Labels and title
plt.xlabel('Latency', fontsize=20)
plt.ylabel('Normalized Radius', fontsize=20)
plt.title('All Worms: Latency vs. Normalized Radius', fontsize=16)

plt.savefig('/Users/iuliarusu/Documents/Sharpee/final_images/figure2/radius_latency.svg', format='svg', bbox_inches='tight')
plt.show()

# Display Pearson correlation coefficient and p-value
corr_coef, p_value
# Out:
# (-0.6947936378507787, 7.492130354429424e-28)

# %%
# Extract relevant data without adding (0,0)
x = combined['latency']
y = combined['normalized_by_worm']

# Compute Pearson correlation coefficient and linear regression line
corr_coef, p_value = stats.pearsonr(x, y)
slope, intercept, _, _, _ = stats.linregress(x, y)

# Generate regression line
x_vals = np.linspace(x.min(), x.max(), 100)  # Regression line over real data range
y_vals = slope * x_vals + intercept

# Create figure and axes
fig, ax = plt.subplots(figsize=(7, 5))

# Plot scatter plot
ax.scatter(x, y, c=[color_discrete_map.get(cell, 'black') for cell in combined['cell_type']], 
           edgecolor='black', alpha=0.7, label="Data")

# Plot regression line
ax.plot(x_vals, y_vals, color='black', linestyle='dashed', linewidth=2, label=f"Pearson r = {corr_coef:.2f}")

# Adjust axes to start at 0 with cut-outs
ax.set_xlim(0, x.max())
ax.set_ylim(0, y.max())

# Add cut-out (break symbol) to both axes
ax.spines['left'].set_position(('outward', 10))  # Move y-axis slightly outward
ax.spines['bottom'].set_position(('outward', 10))  # Move x-axis slightly outward
ax.spines['top'].set_visible(False)  # Hide top spine
ax.spines['right'].set_visible(False)  # Hide right spine

# Add break marks on both axes
break_marker_x = [(x.max()*0.1, x.max()*0.12)]
break_marker_y = [(y.max()*0.1, y.max()*0.12)]

for bx in break_marker_x:
    ax.plot(bx, [0, 0], "k", linewidth=2)  # X-axis break

for by in break_marker_y:
    ax.plot([0, 0], by, "k", linewidth=2)  # Y-axis break

# Labels and title
ax.set_xlabel('Latency', fontsize=14)
ax.set_ylabel('Normalized Radius', fontsize=14)
ax.set_title('All Worms: Latency vs. Normalized Radius', fontsize=16)
ax.legend()

plt.show()

# Display Pearson correlation coefficient and p-value
corr_coef, p_value
# Out:
# (-0.6947936378507787, 7.492130354429424e-28)

# %%
stats.pearsonr(combined['latency'], combined['normalized_by_worm'])
# Out:
# PearsonRResult(statistic=-0.6947936378507787, pvalue=7.492130354429424e-28)

# %%
# Filter AVA and RME values
ava_values = combined[combined['cell_type'] == 'AVA'][0]
rme_values = combined[combined['cell_type'] == 'RME'][0]
smdd_values = combined[combined['cell_type'] == 'SMDD'][0]
smdv_values = combined[combined['cell_type'] == 'SMDV'][0]
on_values = combined[combined['cell_type'] == 'ON'][0]
off_values = combined[combined['cell_type'] == 'OFF'][0]

# Filter other cell types
other_values = combined[~combined['cell_type'].isin(['AVA', 'RME'])][0]

# One-sided t-tests (alternative='less' means testing if AVA/RME are smaller)
t_ava, p_ava = ttest_ind(ava_values, other_values, alternative='less', equal_var=False)
# t_ava, p_ava = ttest_ind(ava_values, on_values, alternative='less', equal_var=False)
# t_ava, p_ava = ttest_ind(ava_values, smdd_values, alternative='less', equal_var=False)
# t_rme, p_rme = ttest_ind(rme_values, on_values, alternative='less', equal_var=False)
t_rme, p_rme = ttest_ind(rme_values, other_values, alternative='less', equal_var=False)


print(f"AVA vs Others: t={t_ava:.3f}, p={p_ava:.3e}")
print(f"RME vs Others: t={t_rme:.3f}, p={p_rme:.3e}")
# Out:
# AVA vs Others: t=-2.271, p=1.324e-02
# RME vs Others: t=-2.307, p=1.165e-02

# %%
ava_values = combined[combined['cell_type'] == 'AVA'][0]
rme_values = combined[combined['cell_type'] == 'RME'][0]
smdd_values = combined[combined['cell_type'] == 'SMDD'][0]
smdv_values = combined[combined['cell_type'] == 'SMDV'][0]
on_values = combined[combined['cell_type'] == 'ON'][0]
off_values = combined[combined['cell_type'] == 'OFF'][0]

# %%
combined
# Out:
#             0 cell_type  latency  normalized_0
# 0    1.900446        ON       20      0.590958
# 1    1.951433        ON       20      0.606813
# 2    1.860834        ON       20      0.578640
# 3    1.892517        ON       20      0.588492
# 4    1.873417        ON       20      0.582553
# ..        ...       ...      ...           ...
# 179  1.663927       RME       72      0.569698
# 180  1.859762      SMDV       60      0.560729
# 181  1.945893      SMDV       60      0.586697
# 182  1.964453      SMDD       33      0.606378
# 183  1.958567      SMDD       33      0.604561
#
# [184 rows x 4 columns]

# %%
latencies = {
    cell_type: combined[combined['cell_type'] == cell_type][0] 
    for cell_type in combined['cell_type'].unique()
}

# %%
# Function to perform t-tests between two groups
def ttest_run(c1, c2):
    """Perform an independent t-test between two cell types."""
    results = stats.ttest_ind(latencies[c1], latencies[c2], equal_var=False)  # Welch's t-test
    df = pd.DataFrame({'categ1': [c1],   # Cell type 1
                       'categ2': [c2],   # Cell type 2
                       'tstat': [results.statistic],  
                       'pvalue': [results.pvalue]})   
    return df

# %%
latencies_pvalues = [ttest_run(i, j) for i, j in combinations(latencies.keys(), 2)]

# %%
norm_latencies_1 = {
    cell_type: combined[combined['cell_type'] == cell_type]['normalized_1'] 
    for cell_type in combined['cell_type'].unique()
}

# %%
norm_latencies_pvals = [ttest_run(i, j) for i, j in combinations(norm_latencies_1.keys(), 2)]

# %%
norm_latencies_pvals
# Out:
# [  categ1 categ2     tstat    pvalue
#  0     ON    OFF -0.133236  0.894442,
#    categ1 categ2     tstat    pvalue
#  0     ON    AVA  1.598518  0.114113,
#    categ1 categ2     tstat    pvalue
#  0     ON    RME  1.550781  0.124511,
#    categ1 categ2     tstat    pvalue
#  0     ON   SMDV -0.952531  0.352849,
#    categ1 categ2     tstat    pvalue
#  0     ON   SMDD -0.812718  0.427415,
#    categ1 categ2     tstat    pvalue
#  0    OFF    AVA  1.526956  0.131882,
#    categ1 categ2     tstat    pvalue
#  0    OFF    RME  1.467974  0.147329,
#    categ1 categ2     tstat    pvalue
#  0    OFF   SMDV -0.813401  0.424414,
#    categ1 categ2     tstat    pvalue
#  0    OFF   SMDD -0.666668  0.512092,
#    categ1 categ2     tstat    pvalue
#  0    AVA    RME -0.160262  0.873107,
#    categ1 categ2     tstat    pvalue
#  0    AVA   SMDV -1.916621  0.069507,
#    categ1 categ2     tstat    pvalue
#  0    AVA   SMDD -1.861986  0.078346,
#    categ1 categ2     tstat   pvalue
# ...

# %% [markdown]
# # Centered HMDS Analysis

# %%
# %store -r w0_3d_pcoords
# %store -r w1_3d_pcoords
# %store -r w2_3d_pcoords
# %store -r w3_3d_pcoords
# %store -r w4_3d_pcoords
# %store -r w5_3d_pcoords
# %store -r w6_3d_pcoords

# %%
all_stim_3d_pcoords_df = pd.DataFrame(np.concatenate([w0_3d_pcoords, w1_3d_pcoords, w2_3d_pcoords, w3_3d_pcoords, w4_3d_pcoords, w5_3d_pcoords, w6_3d_pcoords], axis = 0))

# %%
all_stim_3d_pcoords_df.iloc[:,  -1].unique()
# Out:
# array([nan, 'ON', 'OFF', 'AVA', 'RME', 'SMDV', 'SMDD'], dtype=object)

# %%
"""Centers points based on mean of each vectors component, 
works with 3d coordinates"""
def center_points(df):
    df_copy = df.copy()
    labels = df_copy.iloc[:, -1] #last column is labels
    df_copy = df_copy.iloc[:, : -1] #drop last column
    if df_copy.shape[1] != 3:
        raise ValueError("DataFrame must have exactly 3 coordinate columns before centering.")
    
    df_copy.columns = ['x', 'y', 'z']
    # df_copy['x'] = df_copy['x'] - df_copy['x'].mean()
    # df_copy['y'] = df_copy['y'] - df_copy['y'].mean()
    # df_copy['z'] = df_copy['z'] - df_copy['z'].mean()
    CM = df_copy.mean(axis=0)
    
   
    
    return df_copy, CM, labels

# %%
"""Anoop's Processing functions, translates points about the center """

def poincare_translation(v, x):
   """
   Isometric translation of point x in poincare coordinates.
   Hyperbolic translations are defined by how the origin is translated. Returns the
   translated position of x if the origin were to be translated to v.
   """
   
   dp = v.dot(x)
   v2 = v.dot(v)
   x2 = x.dot(x)
   
   return ((1.0 + 2.0*dp + x2)*v + (1.0 - v2)*x) / (1.0 + 2.0*dp + x2*v2)

def re_center(p_coords, CM_pc):
   """
   given poincare coordinates and ther center of mass, return the isometric translation of
   points so that the CM is now at the origin
   """
   p_coords_array = np.asarray(p_coords)
   return np.asarray([poincare_translation(-CM_pc, pt) for pt in p_coords_array])

# %%
#calculate radii according to Poincare disc model

def calculate_radius(points):
    """Calculate radius of points according to Poincare disc model, used on
    already mean centered and translated pints"""
    radii = []
    for i in range(len(points)):
        norm_sq = np.linalg.norm(points[i])**2
        radius = np.arccosh(1 + (2* norm_sq)/(1 - norm_sq) ) 
        radii.append(radius)
    radii = np.array(radii)
   
    return radii

# %%
#recetner, translate, and obtain radii

centered_points, CM, radii_labels = center_points(all_stim_3d_pcoords_df)
re_centered = re_center( all_stim_3d_pcoords_df.iloc[:, : -1],CM)
radii = calculate_radius(re_centered)

# %%
re_centered.mean(axis=0)
# Out:
# array([0.0007565755684013428, -0.004233814775779872, 0.02433186536003373],
#       dtype=object)

# %%
radii_df = pd.DataFrame(radii, columns = ['radius'])

# %%
radii_df['cell_type'] = radii_labels

# %%
radii_df
# Out:
#        radius cell_type
# 0    4.821377       NaN
# 1    4.418313       NaN
# 2    4.066626       NaN
# 3    3.959098       NaN
# 4    4.585646       NaN
# ..        ...       ...
# 937  3.801796       NaN
# 938  4.261091       NaN
# 939  4.544985       NaN
# 940  4.457569       NaN
# 941  4.535754       NaN
#
# [942 rows x 2 columns]

# %%
cell_types = ['ON', 'OFF', 'AVA', 'RME', 'SMDV', 'SMDD']

# Filter the DataFrame to include only the specified cell types
filtered_rad_df = radii_df[radii_df['cell_type'].isin(cell_types)]

# Map the 'cell_type' column to the corresponding latency values
filtered_rad_df['latency'] = filtered_rad_df['cell_type'].map(latency)
# Out:
# /var/folders/4x/v6r504vx43l3xd43p7kmbr400000gn/T/ipykernel_94054/2225318253.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_rad_df['latency'] = filtered_rad_df['cell_type'].map(latency)

# %%
filtered_rad_df
# Out:
#        radius cell_type  latency
# 103  4.197236        ON       20
# 104  4.324188        ON       20
# 105  4.024147        ON       20
# 106  4.181936        ON       20
# 107  4.115152        ON       20
# ..        ...       ...      ...
# 805  3.982183        ON       20
# 806  4.149710        ON       20
# 807  4.478841        ON       20
# 808  4.661819        ON       20
# 809  4.878333        ON       20
#
# [136 rows x 3 columns]

# %%
color_discrete_map = {
    'ON': 'teal',
    'OFF': '#FF8C00',  # Dark orange
    'AVA': 'red',
    'RME': 'blue',
    'SMDV': 'purple',
    'SMDD': 'yellow'
}


colors = filtered_rad_df['cell_type'].map(color_discrete_map)


plt.figure(figsize=(7, 5))
plt.scatter(filtered_rad_df['latency'], filtered_rad_df['radius'], c=colors, edgecolor='black', alpha=0.7)

plt.xlabel('Latency', fontsize=14)
plt.ylabel('Normalized Radius', fontsize=14)
plt.title('Renormalized Worms: Latency vs. Normalized Radius', fontsize=16)

plt.show()
