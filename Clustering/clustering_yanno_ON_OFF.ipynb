# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import pearsonr


'''
Compare representative clusters in the Yanno.npz to the rest of the Y_full dataset to retrieve the AVA, RME, SMDV,SMDD clusters 
for each worm.
'''
# Out:
# '\nCompare representative clusters in the Yanno.npz to the rest of the Y_full dataset to retrieve the AVA, RME, SMDV,SMDD clusters \nfor each worm.\n'

# %%
stimulus = np.load('../ProcAiryData/inpfull_op50_SF.npz')

ON_cells = np.load('../ProcAiryData/Yop50_SF_psON.npz')
OFF_cells = np.load('../ProcAiryData/Yop50_SF_psOFF.npz')
Y_full = np.load('../ProcAiryData/Yfull_op50_SF.npz')

yanno = np.load('../ProcAiryData/Yanno_op50_SF.npz')

# %%
ON = pd.read_csv('/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/ON_cluster.csv') 
OFF = pd.read_csv('/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/OFF_cluster.csv')

# %%
ON.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0          22  0.111328  0.113690  0.104047  0.097544  0.128698  0.096889
# 1          39  0.111844  0.125500  0.085508  0.112997  0.101238  0.122276
# 2          47  0.192604  0.220196  0.185329  0.198972  0.199652  0.214086
# 3          54  0.123674  0.123468  0.094402  0.088443  0.088383  0.105112
# 4          57  0.999277  0.966674  1.000000  0.947146  0.234203  0.886421
#
#           6         7         8  ...      1592      1593      1594      1595  \
# 0  0.113149  0.091761  0.110592  ...  0.094158  0.087761  0.072876  0.105107
# 1  0.166369  0.147508  0.098558  ...  0.090089  0.147703  0.164014  0.274072
# 2  0.204000  0.212617  0.200606  ...  0.117549  0.125827  0.116286  0.147985
# 3  0.108088  0.097864  0.118637  ...  0.069045  0.070331  0.098578  0.078554
# 4  0.281143  0.251201  0.157087  ...  0.054529  0.148310  0.246808  0.267268
#
#        1596      1597      1598      1599  worm_id  stim_group
# 0  0.077777  0.120296  0.086403  0.073250        0           0
# 1  0.282609  0.370823  0.395895  0.326826        0           0
# 2  0.199686  0.212018  0.182312  0.149742        0           0
# 3  0.111078  0.113384  0.065145  0.054949        0           0
# 4  0.320307  0.321483  0.281932  0.206321        0           0
#
# [5 rows x 1603 columns]

# %%
ON.values
# Out:
# array([[2.20000000e+01, 1.11328090e-01, 1.13690141e-01, ...,
#         7.32498466e-02, 0.00000000e+00, 0.00000000e+00],
#        [3.90000000e+01, 1.11844192e-01, 1.25499752e-01, ...,
#         3.26826011e-01, 0.00000000e+00, 0.00000000e+00],
#        [4.70000000e+01, 1.92603892e-01, 2.20195988e-01, ...,
#         1.49741936e-01, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [8.88000000e+02, 3.62101270e-01, 4.73233423e-01, ...,
#         7.56882645e-02, 6.00000000e+00, 0.00000000e+00],
#        [9.05000000e+02, 1.77397884e-01, 1.58208765e-01, ...,
#         1.18796265e-01, 6.00000000e+00, 0.00000000e+00],
#        [9.16000000e+02, 3.29137233e-01, 3.00833936e-01, ...,
#         2.75317751e-01, 6.00000000e+00, 0.00000000e+00]])

# %%
ON.values[0 , 1 : -3]
# Out:
# array([0.11132809, 0.11369014, 0.10404651, ..., 0.07777653, 0.12029641,
#        0.08640344])

# %%
fig, ax = plt.subplots(figsize=(20, 5))
ax.plot(stimulus['arr_2'])
ax.plot(OFF.values[40 , 1 : -3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 3
#       1 fig, ax = plt.subplots(figsize=(20, 5))
#       2 ax.plot(stimulus['arr_2'])
# ----> 3 ax.plot(OFF.values[40 , 1 : -3])
#
# IndexError: index 40 is out of bounds for axis 0 with size 31

# %%
yanno_full = np.concatenate([yanno['arr_0'], yanno['arr_1'], yanno['arr_2'], yanno['arr_3'], yanno['arr_4'], yanno['arr_5'], yanno['arr_6']], axis = 1 )
yanno_full_df = pd.DataFrame(yanno_full.T)

# %%
#obtain the worm id data, and stimulus group data to Y_full, add these as columns, create a data frame
column = [0] * len(Y_full['arr_0'].T) + [1] * len(Y_full['arr_1'].T) + [2] * len(Y_full['arr_2'].T) + [3] * len(Y_full['arr_3'].T) + [4] * len(Y_full['arr_4'].T) + [5] * len(Y_full['arr_5'].T) + [6] * len(Y_full['arr_6'].T)
worm_id = np.array(column)
Y_full_concat = np.concatenate([Y_full['arr_0'],
                         Y_full['arr_1'],
                         Y_full['arr_2'],
                         Y_full['arr_3'] , Y_full['arr_4'], Y_full['arr_5'], Y_full['arr_6']], axis =1)

Y_full_df = pd.DataFrame(Y_full_concat)
Y_full_df = Y_full_df.T
Y_full_df['worm_id'] = worm_id
stim_g = [0] * len(Y_full['arr_0'].T) + [0] * len(Y_full['arr_1'].T) + [1] * len(Y_full['arr_2'].T) + [1] * len(Y_full['arr_3'].T) + [1] * len(Y_full['arr_4'].T) + [1] * len(Y_full['arr_5'].T) + [0] * len(Y_full['arr_6'].T)
stim_group = np.array(stim_g)
Y_full_df['stim_group'] = stim_group

# %%
Y_full_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1    0.976775  0.991876  0.959301  0.965111  1.000000  0.866721  0.973716
# 2    1.000000  0.935644  0.849705  0.845024  0.842825  0.796130  0.830378
# 3    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4    0.006261  0.006576  0.010239  0.005997  0.007404  0.024813  0.017438
# ..        ...       ...       ...       ...       ...       ...       ...
# 943  0.312603  0.373691  0.449884  0.211660  0.296990  0.187166  0.155247
# 944  0.339387  0.229637  0.216102  0.259927  0.271875  0.270550  0.188673
# 945  0.609380  0.697251  0.636031  0.447529  0.618746  0.642954  0.630861
# 946  0.647262  0.867968  0.824434  0.814158  0.832059  0.911042  0.729391
# 947  0.899194  0.912440  0.929142  0.829083  0.806948  0.862441  1.000000
#
#             7         8         9  ...      1592      1593      1594  \
# 0    0.000000  0.000000  0.000000  ...  0.010237  0.013933  0.005688
# 1    0.923286  0.930305  0.918496  ...  0.472877  0.476172  0.437171
# 2    0.804948  0.761474  0.780609  ...  0.330972  0.342765  0.340209
# 3    0.000000  0.000000  0.000000  ...  0.022308  0.021005  0.025381
# 4    0.033881  0.013081  0.004452  ...  0.367689  0.421811  0.411161
# ..        ...       ...       ...  ...       ...       ...       ...
# 943  0.316095  0.315492  0.300387  ...  0.885284  0.670388  0.661178
# 944  0.265596  0.249477  0.192825  ...  0.982645  1.000000  0.890944
# 945  0.547182  0.689178  0.635459  ...  0.794571  0.945617  0.774464
# 946  1.000000  0.675456  0.825304  ...  0.112071  0.324665  0.324407
# 947  0.895770  0.959122  0.802569  ...  0.373839  0.553614  0.579216
#
#          1595      1596      1597      1598      1599  worm_id  stim_group
# 0    0.014389  0.012715  0.012774  0.006379  0.011325        0           0
# 1    0.449895  0.442183  0.454118  0.467614  0.439026        0           0
# 2    0.350782  0.289997  0.341319  0.324467  0.307941        0           0
# 3    0.005841  0.004750  0.016866  0.017452  0.028150        0           0
# 4    0.503685  0.509207  0.513564  0.600296  0.730846        0           0
# ..        ...       ...       ...       ...       ...      ...         ...
# 943  0.734529  0.851483  0.804422  0.742671  0.777773        6           0
# 944  0.841802  0.882466  0.844906  0.699990  0.825467        6           0
# 945  0.810107  0.714264  0.899256  0.821404  0.950433        6           0
# 946  0.237952  0.371768  0.252458  0.312875  0.207396        6           0
# 947  0.476771  0.543722  0.651135  0.565086  0.584334        6           0
#
# [948 rows x 1602 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 5))

# %%
#use ON/OFF cells data to obtain a mask 
sensory_concat = np.concatenate([ON_cells['arr_0'], ON_cells['arr_1'], ON_cells['arr_2'], ON_cells['arr_3'], ON_cells['arr_4'], ON_cells['arr_5'], ON_cells['arr_6'],
                                  OFF_cells['arr_0'], OFF_cells['arr_1'], OFF_cells['arr_2'], OFF_cells['arr_3'], OFF_cells['arr_4'], OFF_cells['arr_5'], OFF_cells['arr_6']], axis = 1)

sensory_df = pd.DataFrame(sensory_concat)

# Merge the DataFrames on columns 'A' and 'B'
merged_df = pd.merge(Y_full_df.iloc[:, : -2], sensory_df.T, how='outer', indicator = True)
both = merged_df[merged_df['_merge'] == 'both']
#indexes of sensory neurons in the original dataframe
index_array = np.array(both.index)

# %%
ON_cells = pd.DataFrame(np.concatenate([ON_cells['arr_0'], ON_cells['arr_1'], ON_cells['arr_2'], ON_cells['arr_3'], ON_cells['arr_4'], ON_cells['arr_5'], ON_cells['arr_6']], axis =1))
OFF_cells = pd.DataFrame(np.concatenate([OFF_cells['arr_0'], OFF_cells['arr_1'], OFF_cells['arr_2'], OFF_cells['arr_3'], OFF_cells['arr_4'], OFF_cells['arr_5'], OFF_cells['arr_6']], axis = 1))

# %%
ON_cells = ON_cells.T
OFF_cells = OFF_cells.T

# %%
ON_ids = np.array(ON_cells.shape[0] * ['ON'])
OFF_ids = np.array(OFF_cells.shape[0] * ['OFF'])

# %%
sensory_df_w_ids = pd.concat([ON_cells, OFF_cells], axis = 1)

# %%
#add additional column to sensory data sets to have their id
ON_cells['cell_id'] = ON_ids
OFF_cells ['cell_id'] = OFF_ids

# %%
sensory_df_w_ids = pd.concat([ON_cells, OFF_cells], axis = 0)

# %%
sensory_df_w_ids.reset_index(drop=True, inplace=True)

# %%
merged_df_labels = pd.merge(Y_full_df.iloc[:, : -2], sensory_df_w_ids.iloc[:, : -1].T, how='outer', indicator = True)
both_labels = merged_df_labels[merged_df_labels['_merge'] == 'both']
#indexes of sensory neurons in the original dataframe
index_array_labels = np.array(both_labels.index)

# %%
#optional
# Create a mask where True indicates indices NOT to be removed: tilda ~ inverts the mask
sensory_mask = Y_full_df.index.isin(index_array)

# Filter the DataFrame to keep only rows not in index_array
Y_full_sensory = Y_full_df[sensory_mask]

# Print the updated DataFrame
#Y_full_filtered.shape

# %%
# Create a boolean mask where the condition is met
worm_mask = Y_full_df['worm_id'] == 0

# Filter the DataFrame using the mask
worm_filter0 = Y_full_df[worm_mask]

# %%
worm_filter0 = Y_full_df[Y_full_df['worm_id'] == 0]
worm_filter1 = Y_full_df[Y_full_df['worm_id'] == 1]
worm_filter2 = Y_full_df[Y_full_df['worm_id'] == 2]
worm_filter3 = Y_full_df[Y_full_df['worm_id'] == 3]
worm_filter4 = Y_full_df[Y_full_df['worm_id'] == 4]
worm_filter5 = Y_full_df[Y_full_df['worm_id'] == 5]
worm_filter6 = Y_full_df[Y_full_df['worm_id'] == 6]

# %%
worm_filter1.reset_index(drop=False)
# Out:
#      index         0         1         2         3         4         5  \
# 0      133  1.000000  0.905931  0.908609  0.856746  0.893340  0.863641
# 1      134  0.077771  0.050388  0.038936  0.063386  0.057993  0.087070
# 2      135  0.975239  1.000000  0.874300  0.948862  0.851982  0.856271
# 3      136  0.823890  0.801902  0.904354  0.911403  0.818948  0.781939
# 4      137  1.000000  0.860864  0.710613  0.847181  0.691585  0.950200
# ..     ...       ...       ...       ...       ...       ...       ...
# 130    263  0.463999  0.667145  0.611119  0.544210  0.584522  0.748056
# 131    264  0.402063  0.640224  0.644778  0.197973  0.530774  0.783067
# 132    265  0.754290  0.750264  0.712927  0.668441  0.736813  0.638217
# 133    266  0.586850  1.000000  0.549500  0.659907  0.743847  0.658546
# 134    267  0.552949  0.625529  0.694780  0.645331  0.596760  0.514333
#
#             6         7         8  ...      1592      1593      1594  \
# 0    0.877859  0.843457  0.835619  ...  0.019652  0.011284  0.009203
# 1    0.068161  0.045648  0.060495  ...  0.074979  0.084153  0.108473
# 2    0.888841  0.832827  0.740973  ...  0.025000  0.027849  0.037620
# 3    0.786081  0.875620  0.793138  ...  0.018912  0.023293  0.014396
# 4    0.699065  0.683294  0.680645  ...  0.124312  0.139668  0.058358
# ..        ...       ...       ...  ...       ...       ...       ...
# 130  0.677390  0.658209  0.572425  ...  0.254330  0.307176  0.344242
# 131  0.547512  0.521685  0.256643  ...  0.369270  0.403139  0.312778
# 132  0.770452  0.606766  0.710431  ...  0.528450  0.460993  0.391231
# 133  0.609202  0.689420  0.864819  ...  0.198562  0.345187  0.184583
# 134  0.609785  0.619125  0.666125  ...  0.225004  0.161802  0.264078
#
#          1595      1596      1597      1598      1599  worm_id  stim_group
# 0    0.009176  0.019795  0.016399  0.026988  0.017123        1           0
# 1    0.132419  0.153624  0.178262  0.162290  0.148391        1           0
# 2    0.015074  0.023158  0.014122  0.019873  0.017630        1           0
# 3    0.014568  0.019072  0.012548  0.007302  0.013421        1           0
# 4    0.067660  0.040595  0.085299  0.057844  0.041449        1           0
# ..        ...       ...       ...       ...       ...      ...         ...
# 130  0.332163  0.341828  0.488444  0.433484  0.448613        1           0
# 131  0.186461  0.719301  0.380289  0.658583  0.602718        1           0
# 132  0.345996  0.418494  0.371699  0.233398  0.305946        1           0
# 133  0.114531  0.281628  0.308689  0.211198  0.204829        1           0
# 134  0.122348  0.184505  0.099652  0.139724  0.116358        1           0
#
# [135 rows x 1603 columns]

# %%
worm_filter2.reset_index(drop=False)
worm_filter3.reset_index(drop=False)
worm_filter4.reset_index(drop=False)
worm_filter5.reset_index(drop=False)
worm_filter6.reset_index(drop=False)
# Out:
#      index         0         1         2         3         4         5  \
# 0      815  0.112733  0.107337  0.100175  0.100245  0.106083  0.111660
# 1      816  0.039446  0.022301  0.027821  0.019933  0.017368  0.030563
# 2      817  0.154420  0.167550  0.143571  0.129990  0.159110  0.142375
# 3      818  0.105650  0.119742  0.119879  0.122073  0.123106  0.133294
# 4      819  0.077640  0.073688  0.068214  0.070275  0.071058  0.071268
# ..     ...       ...       ...       ...       ...       ...       ...
# 128    943  0.312603  0.373691  0.449884  0.211660  0.296990  0.187166
# 129    944  0.339387  0.229637  0.216102  0.259927  0.271875  0.270550
# 130    945  0.609380  0.697251  0.636031  0.447529  0.618746  0.642954
# 131    946  0.647262  0.867968  0.824434  0.814158  0.832059  0.911042
# 132    947  0.899194  0.912440  0.929142  0.829083  0.806948  0.862441
#
#             6         7         8  ...      1592      1593      1594  \
# 0    0.103260  0.106675  0.116486  ...  0.000000  0.000000  0.000000
# 1    0.022189  0.018168  0.016653  ...  0.733607  0.682478  0.742351
# 2    0.097211  0.117177  0.116042  ...  0.082539  0.124534  0.123758
# 3    0.124293  0.114933  0.099844  ...  0.021662  0.022798  0.021892
# 4    0.093815  0.084459  0.058994  ...  0.517275  0.617238  0.569414
# ..        ...       ...       ...  ...       ...       ...       ...
# 128  0.155247  0.316095  0.315492  ...  0.885284  0.670388  0.661178
# 129  0.188673  0.265596  0.249477  ...  0.982645  1.000000  0.890944
# 130  0.630861  0.547182  0.689178  ...  0.794571  0.945617  0.774464
# 131  0.729391  1.000000  0.675456  ...  0.112071  0.324665  0.324407
# 132  1.000000  0.895770  0.959122  ...  0.373839  0.553614  0.579216
#
#          1595      1596      1597      1598      1599  worm_id  stim_group
# 0    0.000000  0.000000  0.000000  0.000000  0.000000        6           0
# 1    0.702885  0.669743  0.641642  0.705526  0.665611        6           0
# 2    0.094315  0.091255  0.062677  0.049560  0.037804        6           0
# 3    0.023047  0.009436  0.004118  0.018921  0.007322        6           0
# 4    0.541760  0.581028  0.591669  0.580283  0.532777        6           0
# ..        ...       ...       ...       ...       ...      ...         ...
# 128  0.734529  0.851483  0.804422  0.742671  0.777773        6           0
# 129  0.841802  0.882466  0.844906  0.699990  0.825467        6           0
# 130  0.810107  0.714264  0.899256  0.821404  0.950433        6           0
# 131  0.237952  0.371768  0.252458  0.312875  0.207396        6           0
# 132  0.476771  0.543722  0.651135  0.565086  0.584334        6           0
#
# [133 rows x 1603 columns]

# %%
worm_filter6.reset_index(drop=False)
# Out:
#      index         0         1         2         3         4         5  \
# 0      815  0.112733  0.107337  0.100175  0.100245  0.106083  0.111660
# 1      816  0.039446  0.022301  0.027821  0.019933  0.017368  0.030563
# 2      817  0.154420  0.167550  0.143571  0.129990  0.159110  0.142375
# 3      818  0.105650  0.119742  0.119879  0.122073  0.123106  0.133294
# 4      819  0.077640  0.073688  0.068214  0.070275  0.071058  0.071268
# ..     ...       ...       ...       ...       ...       ...       ...
# 128    943  0.312603  0.373691  0.449884  0.211660  0.296990  0.187166
# 129    944  0.339387  0.229637  0.216102  0.259927  0.271875  0.270550
# 130    945  0.609380  0.697251  0.636031  0.447529  0.618746  0.642954
# 131    946  0.647262  0.867968  0.824434  0.814158  0.832059  0.911042
# 132    947  0.899194  0.912440  0.929142  0.829083  0.806948  0.862441
#
#             6         7         8  ...      1592      1593      1594  \
# 0    0.103260  0.106675  0.116486  ...  0.000000  0.000000  0.000000
# 1    0.022189  0.018168  0.016653  ...  0.733607  0.682478  0.742351
# 2    0.097211  0.117177  0.116042  ...  0.082539  0.124534  0.123758
# 3    0.124293  0.114933  0.099844  ...  0.021662  0.022798  0.021892
# 4    0.093815  0.084459  0.058994  ...  0.517275  0.617238  0.569414
# ..        ...       ...       ...  ...       ...       ...       ...
# 128  0.155247  0.316095  0.315492  ...  0.885284  0.670388  0.661178
# 129  0.188673  0.265596  0.249477  ...  0.982645  1.000000  0.890944
# 130  0.630861  0.547182  0.689178  ...  0.794571  0.945617  0.774464
# 131  0.729391  1.000000  0.675456  ...  0.112071  0.324665  0.324407
# 132  1.000000  0.895770  0.959122  ...  0.373839  0.553614  0.579216
#
#          1595      1596      1597      1598      1599  worm_id  stim_group
# 0    0.000000  0.000000  0.000000  0.000000  0.000000        6           0
# 1    0.702885  0.669743  0.641642  0.705526  0.665611        6           0
# 2    0.094315  0.091255  0.062677  0.049560  0.037804        6           0
# 3    0.023047  0.009436  0.004118  0.018921  0.007322        6           0
# 4    0.541760  0.581028  0.591669  0.580283  0.532777        6           0
# ..        ...       ...       ...       ...       ...      ...         ...
# 128  0.734529  0.851483  0.804422  0.742671  0.777773        6           0
# 129  0.841802  0.882466  0.844906  0.699990  0.825467        6           0
# 130  0.810107  0.714264  0.899256  0.821404  0.950433        6           0
# 131  0.237952  0.371768  0.252458  0.312875  0.207396        6           0
# 132  0.476771  0.543722  0.651135  0.565086  0.584334        6           0
#
# [133 rows x 1603 columns]

# %% [markdown]
# ## find more ON and OFF cells in each worm

# %%
fig, ax = plt.subplots(figsize=(25, 5))
ax.plot(stimulus['arr_6'])
ax.plot(range(1600), Y_full_df.iloc[947
                                    
                                    , : -2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 fig, ax = plt.subplots(figsize=(25, 5))
#       2 ax.plot(stimulus['arr_6'])
# ----> 3 ax.plot(range(1600), Y_full_df.iloc[947
#       4
#       5                                     , : -2])
#
# NameError: name 'Y_full_df' is not defined

# %%
stimulus['arr_0'].reshape(-1).shape
# Out:
# (1600,)

# %%
ON_ids = [22, 39, 47, 54, 57, 59, 90, 107, 134, 143, 180, 192, 200, 258, 270, 281, 306, 343, 406, 419, 434, 444, 487, 509, 554, 574, 576, 581, 643, 686, 695, 709, 710, 714, 719, 724, 762, 785, 789, 822, 825, 827, 888, 905, 916]
OFF_ids = [15, 38, 48, 81, 97, 98, 131, 154, 177, 188, 206, 249, 271, 301, 326, 400, 412, 417, 450, 495, 518, 531, 550, 682, 701, 783, 788, 806, 828, 875, 880]

# %%
ON_cluster = Y_full_df.loc[ON_ids]  
OFF_cluster = Y_full_df.loc[OFF_ids]

# %%
# %store ON_cluster
# %store OFF_cluster
# Out:
#             0         1         2         3         4         5         6  \
# 22   0.111328  0.113690  0.104047  0.097544  0.128698  0.096889  0.113149
# 39   0.111844  0.125500  0.085508  0.112997  0.101238  0.122276  0.166369
# 47   0.192604  0.220196  0.185329  0.198972  0.199652  0.214086  0.204000
# 54   0.123674  0.123468  0.094402  0.088443  0.088383  0.105112  0.108088
# 57   0.999277  0.966674  1.000000  0.947146  0.234203  0.886421  0.281143
# 59   0.257971  0.260115  0.268479  0.246232  0.266098  0.242562  0.261012
# 90   0.113358  0.145652  0.110831  0.103521  0.083500  0.087598  0.106528
# 107  0.031882  0.000000  0.056720  0.044798  0.021835  0.004317  0.000000
# 134  0.077771  0.050388  0.038936  0.063386  0.057993  0.087070  0.068161
# 143  0.067608  0.076400  0.083592  0.069296  0.086243  0.072263  0.073743
# 180  0.080728  0.064535  0.051185  0.091795  0.071226  0.070732  0.095991
# 192  0.123334  0.114243  0.156110  0.118286  0.123836  0.131926  0.158052
# 200  0.205371  0.175247  0.193966  0.175695  0.203902  0.102485  0.187159
# 258  0.372543  0.261307  0.301445  0.299415  0.319310  0.317340  0.224421
# 270  0.058262  0.086767  0.081537  0.076845  0.070099  0.081335  0.054870
# 281  0.150208  0.160966  0.145306  0.117003  0.118525  0.139277  0.120724
# 306  0.080219  0.064809  0.066301  0.031171  0.053962  0.069359  0.059205
# 343  0.122627  0.130791  0.198302  0.118159  0.115839  0.110871  0.125026
# 406  0.159077  0.123879  0.099078  0.123546  0.137194  0.137419  0.127255
# 419  0.173799  0.178069  0.161344  0.129538  0.207844  0.139890  0.139467
# 434  0.115975  0.095313  0.093286  0.091781  0.087201  0.098335  0.134092
# 444  0.088103  0.067323  0.077684  0.064646  0.082061  0.062991  0.115118
# 487  0.259403  0.228741  0.221400  0.290031  0.271720  0.202638  0.241657
# 509  0.212629  0.256050  0.238213  0.224120  0.178727  0.271542  0.222806
# 554  0.273137  0.163122  0.152948  0.081554  0.079740  0.071049  0.029784
# 574  0.272752  0.321919  0.073021  0.229013  0.158103  0.106496  0.104422
# 576  0.489314  0.387750  0.463972  0.450340  0.466616  0.345221  0.274876
# 581  0.140011  0.194289  0.185573  0.146715  0.106824  0.130871  0.128565
# 643  0.290252  0.346035  0.255738  0.231234  0.290730  0.313475  0.324228
# 686  0.097190  0.124451  0.103389  0.090180  0.116402  0.117817  0.098016
# 695  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 709  0.007268  0.010954  0.037007  0.002865  0.020688  0.024091  0.016025
# 710  0.260169  0.222263  0.208922  0.188534  0.275513  0.255970  0.251932
# 714  0.068478  0.103694  0.076152  0.071061  0.070682  0.044382  0.079700
# 719  0.133891  0.069667  0.113027  0.131902  0.101475  0.086520  0.089080
# 724  0.044767  0.034356  0.054277  0.060201  0.064883  0.034744  0.045008
# 762  0.097807  0.110076  0.053315  0.072416  0.069055  0.097242  0.099662
# 785  0.160772  0.154216  0.216285  0.149779  0.153130  0.155769  0.150393
# 789  0.147155  0.089371  0.084104  0.108654  0.072653  0.089613  0.097006
# 822  0.073245  0.078041  0.101136  0.097770  0.070143  0.089184  0.103075
# 825  0.091930  0.081861  0.077892  0.061712  0.050784  0.066130  0.067389
# 827  0.106613  0.120760  0.123206  0.097683  0.112920  0.109616  0.110692
# 888  0.362101  0.473233  0.372889  0.277051  0.377416  0.286610  0.270997
# 905  0.177398  0.158209  0.138255  0.142745  0.166383  0.124305  0.177825
# 916  0.329137  0.300834  0.240092  0.287031  0.335353  0.275898  0.366333
#
#             7         8         9  ...      1592      1593      1594  \
# 22   0.091761  0.110592  0.098088  ...  0.094158  0.087761  0.072876
# 39   0.147508  0.098558  0.156589  ...  0.090089  0.147703  0.164014
# 47   0.212617  0.200606  0.209405  ...  0.117549  0.125827  0.116286
# 54   0.097864  0.118637  0.101049  ...  0.069045  0.070331  0.098578
# 57   0.251201  0.157087  0.222240  ...  0.054529  0.148310  0.246808
# 59   0.225937  0.200361  0.212038  ...  0.046181  0.052980  0.051662
# 90   0.126235  0.104085  0.136004  ...  0.075667  0.066197  0.059868
# 107  0.000000  0.045460  0.015600  ...  0.450036  0.273016  0.323943
# 134  0.045648  0.060495  0.052107  ...  0.074979  0.084153  0.108473
# 143  0.054932  0.059659  0.081850  ...  0.095291  0.106757  0.142643
# 180  0.076983  0.087476  0.066952  ...  0.028746  0.045381  0.071975
# 192  0.132808  0.139767  0.162605  ...  0.069008  0.075413  0.069472
# 200  0.170857  0.200971  0.180125  ...  0.091389  0.122850  0.170404
# 258  0.327617  0.252720  0.275392  ...  0.111232  0.082927  0.165723
# 270  0.060780  0.080764  0.076667  ...  0.003032  0.000000  0.012079
# 281  0.127236  0.105254  0.109680  ...  0.057380  0.055165  0.047697
# 306  0.064676  0.084366  0.110546  ...  0.058390  0.041855  0.037438
# 343  0.127222  0.111505  0.096929  ...  0.043508  0.055072  0.059692
# 406  0.122023  0.113864  0.125521  ...  0.061156  0.073317  0.063977
# 419  0.117953  0.162625  0.186763  ...  0.040630  0.052157  0.015773
# 434  0.124130  0.110751  0.125594  ...  0.083985  0.066006  0.094865
# 444  0.081729  0.098955  0.117504  ...  0.028323  0.054187  0.033205
# 487  0.255706  0.271070  0.204249  ...  0.156069  0.244371  0.234651
# 509  0.265489  0.216213  0.239744  ...  0.257596  0.215376  0.223803
# 554  0.093475  0.051165  0.083308  ...  0.015904  0.003935  0.011398
# 574  0.000000  0.078507  0.000000  ...  0.000000  0.004703  0.000000
# 576  0.276127  0.303347  0.201551  ...  0.048084  0.012956  0.042221
# 581  0.094061  0.121795  0.134898  ...  0.026475  0.049415  0.038540
# 643  0.219817  0.247650  0.277177  ...  0.135764  0.169782  0.129274
# 686  0.093534  0.104286  0.100644  ...  0.039363  0.022013  0.013730
# 695  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 709  0.086438  0.027677  0.065741  ...  0.092301  0.000000  0.087930
# 710  0.248553  0.184955  0.241812  ...  0.030390  0.000000  0.040954
# 714  0.079513  0.084491  0.064218  ...  0.035361  0.069473  0.059735
# 719  0.117927  0.103042  0.104133  ...  0.059264  0.067043  0.066581
# 724  0.051906  0.079890  0.073879  ...  0.019260  0.010417  0.014744
# 762  0.107883  0.013274  0.064901  ...  0.136636  0.107164  0.086676
# 785  0.243710  0.226415  0.189715  ...  0.178537  0.019106  0.204344
# 789  0.113937  0.116631  0.116714  ...  0.139730  0.171303  0.177713
# 822  0.072258  0.083143  0.090620  ...  0.135058  0.149525  0.186902
# 825  0.061638  0.081260  0.066630  ...  0.019614  0.001270  0.000000
# 827  0.113398  0.113115  0.124046  ...  0.000000  0.063073  0.042755
# 888  0.364584  0.339501  0.390854  ...  0.087025  0.076245  0.113256
# 905  0.138692  0.156278  0.150234  ...  0.175833  0.233699  0.299445
# 916  0.324432  0.261443  0.257309  ...  0.163353  0.150703  0.149409
#
#          1595      1596      1597      1598      1599  worm_id  stim_group
# 22   0.105107  0.077777  0.120296  0.086403  0.073250        0           0
# 39   0.274072  0.282609  0.370823  0.395895  0.326826        0           0
# 47   0.147985  0.199686  0.212018  0.182312  0.149742        0           0
# 54   0.078554  0.111078  0.113384  0.065145  0.054949        0           0
# 57   0.267268  0.320307  0.321483  0.281932  0.206321        0           0
# 59   0.082144  0.056758  0.079711  0.104782  0.041585        0           0
# 90   0.049471  0.097512  0.099438  0.067180  0.065756        0           0
# 107  0.431077  0.447732  0.526972  0.523080  0.547556        0           0
# 134  0.132419  0.153624  0.178262  0.162290  0.148391        1           0
# 143  0.171139  0.212862  0.268534  0.178100  0.120161        1           0
# 180  0.079139  0.095690  0.078129  0.056928  0.044414        1           0
# 192  0.079777  0.079524  0.087750  0.078156  0.012485        1           0
# 200  0.220731  0.247057  0.301267  0.207900  0.156760        1           0
# 258  0.288396  0.151586  0.232638  0.224865  0.140482        1           0
# 270  0.016968  0.020956  0.017370  0.014025  0.015286        2           1
# 281  0.045601  0.033571  0.034264  0.021647  0.045542        2           1
# 306  0.039988  0.052700  0.059330  0.046315  0.044140        2           1
# 343  0.051789  0.015224  0.037568  0.034001  0.037996        2           1
# 406  0.053079  0.056482  0.079443  0.055912  0.041999        3           1
# 419  0.072079  0.032221  0.042773  0.050929  0.034311        3           1
# 434  0.092868  0.037412  0.069551  0.080170  0.052520        3           1
# 444  0.029524  0.049617  0.037839  0.036335  0.008672        3           1
# 487  0.236084  0.218869  0.169520  0.205383  0.182958        3           1
# 509  0.216880  0.239264  0.199902  0.194346  0.273063        3           1
# 554  0.027061  0.013832  0.003280  0.015201  0.010456        4           1
# 574  0.000000  0.000000  0.000000  0.000000  0.005001        4           1
# 576  0.043523  0.036298  0.041216  0.000000  0.021526        4           1
# 581  0.058931  0.012506  0.024817  0.038983  0.041672        4           1
# 643  0.169333  0.054088  0.061984  0.080628  0.128268        4           1
# 686  0.016310  0.035816  0.041874  0.051962  0.015311        5           1
# 695  0.000000  0.000000  0.000000  0.000000  0.000000        5           1
# 709  0.000000  0.064883  0.112134  0.160932  0.000000        5           1
# 710  0.000000  0.023827  0.048618  0.062393  0.000000        5           1
# 714  0.056790  0.055669  0.062255  0.018004  0.046081        5           1
# 719  0.030828  0.063669  0.037676  0.022844  0.034804        5           1
# 724  0.000000  0.010609  0.025992  0.030069  0.026731        5           1
# 762  0.145710  0.094362  0.127283  0.097009  0.106204        5           1
# 785  0.000000  0.214345  0.150284  0.214347  0.090494        5           1
# 789  0.163588  0.135366  0.116378  0.165891  0.183176        5           1
# 822  0.225515  0.251903  0.245917  0.210967  0.172567        6           0
# 825  0.022279  0.057171  0.124814  0.095184  0.100705        6           0
# 827  0.031726  0.073070  0.079994  0.052122  0.025359        6           0
# 888  0.147686  0.029469  0.092511  0.066466  0.075688        6           0
# 905  0.266703  0.232073  0.166031  0.174015  0.118796        6           0
# 916  0.199321  0.243796  0.260949  0.279570  0.275318        6           0
#
# [45 rows x 1602 columns]

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/ON_cluster.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
ON_cluster.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/OFF_cluster.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
OFF_cluster.to_csv(file_path, index=True)

# %%
co = []
for i in range(0, worm_filter0.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(stimulus['arr_0'].reshape(-1), worm_filter0.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
ON_0 = np.where(co[:, 1] >= 0.7)

# %%
co
# Out:
# [(0, 0.12198360360258045),
#  (1, -0.21930742284386612),
#  (2, -0.14804053492793867),
#  (3, 0.19353614567558375),
#  (4, -0.038982172948800846),
#  (5, 0.1290321606463214),
#  (6, -0.09609910119427925),
#  (7, -0.1251105695087944),
#  (8, 0.15575730750879466),
#  (9, 0.1949665331659851),
#  (10, -0.10134702456863501),
#  (11, -0.0037308507023735248),
#  (12, 0.015117999296221865),
#  (13, 0.02881317238686722),
#  (14, -0.22181490716104493),
#  (15, -0.4771071019135782),
#  (16, 0.15302649991057735),
#  (17, -0.22276809138520617),
#  (18, -0.12321650423770455),
#  (19, -0.13632182314730157),
#  (20, -0.06858674414050822),
#  (21, -0.13470266573776063),
#  (22, 0.5251575276244772),
#  (23, -0.15536849197118163),
#  (24, -0.18739701309706455),
#  (25, 0.12102891149764777),
#  (26, -0.043998116450547575),
#  (27, 0.1259167719476845),
#  (28, -0.1304896581061984),
#  (29, 0.10591381887355741),
#  (30, -0.01519521988436337),
#  (31, 0.07692453157726495),
#  (32, -0.16009549780132146),
#  (33, 0.07115526545251012),
#  (34, 0.03918428612654447),
#  (35, 0.043494464460170607),
#  (36, -0.14883665095908633),
#  (37, -0.01846604929020671),
#  (38, -0.2968667932471224),
#  (39, 0.48764861624299893),
#  (40, -0.08481153284253266),
#  (41, 0.07249279017045263),
#  (42, -0.1861880012495873),
#  (43, 0.09979085548710923),
#  (44, 0.11113016458462022),
#  (45, -0.17172180304971918),
#  (46, 0.1212969726611469),
#  (47, 0.47531930356897145),
#  (48, -0.2630438518840582),
#  (49, -0.13514072311362085),
#  (50, 0.1776764686379336),
#  (51, -0.04539069814241915),
#  (52, -0.16011205199031062),
#  (53, -0.02504596034847662),
#  (54, 0.5136639553685391),
#  (55, -0.1215234765067286),
#  (56, 0.14954653533695927),
#  (57, 0.38382089690210774),
#  (58, -0.211026097489311),
#  (59, 0.23377742980697694),
#  (60, 0.11477013250753519),
#  (61, 0.1467742071226283),
#  (62, -0.05111944317116153),
#  (63, -0.165655459649598),
#  (64, -0.06831170171837343),
#  (65, 0.020822696794826054),
#  (66, -0.07268789032555699),
#  (67, -0.09627902394598253),
#  (68, -0.069541211808614),
#  (69, -0.043971755077296656),
#  (70, 0.13377838372374143),
#  (71, -0.04347260920586322),
#  (72, 0.014474210076080938),
#  (73, -0.013771249895365913),
#  (74, 0.14354218084867792),
#  (75, 0.05425429597553626),
#  (76, 0.09638638187327364),
#  (77, -0.1475512329350651),
#  (78, -0.08818033467413207),
#  (79, 0.11324086260515664),
#  (80, -0.09473982724054356),
#  (81, -0.5010330288176532),
#  (82, -0.09524792562238144),
#  (83, -0.06384132657683378),
#  (84, 0.043467013942865125),
#  (85, -0.07444431725981651),
#  (86, -0.057604095197321896),
#  (87, -0.08411034755414785),
#  (88, -0.06727368091134789),
#  (89, 0.05258902406548195),
#  (90, 0.5187634412690472),
#  (91, 0.08707801975729629),
#  (92, -0.0919321513323952),
#  (93, -0.08210757356502839),
#  (94, -0.11637476956481722),
#  (95, -0.1309360947795793),
#  (96, 0.08245791991228966),
#  (97, -0.315703080658478),
#  (98, -0.36035954186652364),
#  (99, 0.07580430708512392),
#  (100, -0.009432696871470431),
#  (101, 0.04548700188628225),
#  (102, -0.18865697767395423),
#  (103, -0.013608497103277172),
#  (104, -0.1078690568460918),
#  (105, -0.08685410194660181),
#  (106, -0.107848465881176),
#  (107, 0.411034486819817),
#  (108, -0.01663126986236757),
#  (109, 0.045801965801733215),
#  (110, -0.046179080461794565),
#  (111, -0.027375468799159274),
#  (112, 0.14084849098634705),
#  (113, -0.013349269535448172),
#  (114, 0.09179583688203419),
#  (115, -0.15032437696725384),
#  (116, 0.04195173967294785),
#  (117, -0.05198923865746864),
#  (118, -0.0694869870811266),
#  (119, -0.19712618532552503),
#  (120, -0.09124191339407285),
#  (121, -0.11443100681861143),
#  (122, 0.007007038150414396),
#  (123, -0.09669071497987289),
#  (124, -0.10698381991752967),
#  (125, -0.08811450243169185),
#  (126, -0.10894887014313771),
#  (127, -0.07846954265874288),
#  (128, -0.119388203480849),
#  (129, 0.09653539795762753),
#  (130, 0.08058379540786048),
#  (131, -0.3467267411511896),
#  (132, -0.10733192006182501)]

# %%
ON_0
# Out:
# (array([], dtype=int64),)

# %%
index_array
# Out:
# array([ 92, 141, 143, 157, 166, 169, 174, 185, 192, 194, 209, 214, 232,
#        248, 256, 258, 262, 273, 275, 276, 286, 292, 302, 312, 313, 316,
#        323, 333, 339, 340, 343, 356, 369, 375, 406, 444, 445, 449, 454,
#        460, 487, 580, 588, 598, 617, 625, 633, 636, 643, 758, 899])

# %%
worm_filter0

# %%
yanno_full_df

# %%
co = []
for i in range(0, worm_filter0.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[0, :], worm_filter0.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
AVA_0 = np.where(co[:, 1] >= 0.7)

# %%
AVA_0

# %%
co = []
for i in range(0, worm_filter0.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[1, :], worm_filter0.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
RME_0 = np.where(co[:, 1] >= 0.7)

# %%
RME_0

# %%
co = []
for i in range(0, worm_filter0.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[2, :], worm_filter0.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
SMVD_0 = np.where(co[:, 1] >= 0.7)

# %%
SMVD_0

# %%
co = []
for i in range(0, worm_filter0.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[3, :], worm_filter0.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
SMDD_0 = np.where(co[:, 1] >= 0.7)

# %%
SMDD_0

# %%
RME_0_df = worm_filter0.loc[RME_0]

# %%
AVA_0_df = worm_filter0.loc[AVA_0]
SMDD_0_df = worm_filter0.loc[SMDD_0]
SMVD_0_df = worm_filter0.loc[SMVD_0]

# %%
# %store AVA_0_df 
# %store RME_0_df
# %store SMDD_0_df
# %store SMVD_0_df

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/AVA_0_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
AVA_0_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/RME_0_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
RME_0_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/SMDD_0_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
SMDD_0_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/SMVD_0_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
SMVD_0_df.to_csv(file_path, index=True)

# %% [markdown]
# ## Worm1

# %%
co = []
for i in range(0, worm_filter1.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[4, :], worm_filter1.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
AVA_1 = np.where(co[:, 1] >= 0.7)

# %%
AVA_1

# %%
co = []
for i in range(0, worm_filter1.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[5, :], worm_filter1.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
RME_1 = np.where(co[:, 1] >= 0.7)

# %%
RME_1

# %%
co = []
for i in range(0, worm_filter1.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[6, :], worm_filter1.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
SMDV_1 = np.where(co[:, 1] >= 0.7)

# %%
SMDV_1

# %%
co = []
for i in range(0, worm_filter1.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[7, :], worm_filter1.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
SMDD_1 = np.where(co[:, 1] >= 0.7)

# %%
SMDD_1

# %%
#move worm1 global idx to a new column, and give it standard index
worm_filter1

# Step 1: Extract the first column and save it
global_cell_ids = worm_filter1.index

# Step 2: Drop the first column from the original position
worm_filter1 = worm_filter1.reset_index(drop=True)

# Step 3: Append it to the end of the DataFrame
worm_filter1['Global Cell IDs'] = global_cell_ids

# %%
AVA_1_df = worm_filter1.loc[AVA_1]
RME_1_df = worm_filter1.loc[RME_1]
SMDV_1_df = worm_filter1.loc[SMDV_1]
SMDD_1_df = worm_filter1.loc[SMDD_1]

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/AVA_1_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
AVA_1_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/RME_1_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
RME_1_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/SMDD_1_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
SMDD_1_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/SMDV_1_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
SMDV_1_df.to_csv(file_path, index=True)

# %% [markdown]
# ### Worm2

# %%
co = []
for i in range(0, worm_filter2.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[8, :], worm_filter2.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
AVA_2 = np.where(co[:, 1] >= 0.7)

# %%
AVA_2

# %%
co = []
for i in range(0, worm_filter2.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[9, :], worm_filter2.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
RME_2 = np.where(co[:, 1] >= 0.7)

# %%
RME_2

# %%
co = []
for i in range(0, worm_filter2.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[10, :], worm_filter2.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
SMDD_2 = np.where(co[:, 1] >= 0.7)

# %%
SMDD_2

# %%
co = []
for i in range(0, worm_filter2.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[11, :], worm_filter2.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
SMDV_2 = np.where(co[:, 1] >= 0.7)

# %%
SMDV_2

# %%
#move worm1 global idx to a new column, and give it standard index
worm_filter2

# Step 1: Extract the first column and save it
global_cell_ids = worm_filter2.index

# Step 2: Drop the first column from the original position
worm_filter2 = worm_filter2.reset_index(drop=True)

# Step 3: Append it to the end of the DataFrame
worm_filter2['Global Cell IDs'] = global_cell_ids

# %%
AVA_2_df = worm_filter2.loc[AVA_2]
RME_2_df = worm_filter2.loc[RME_2]
SMDV_2_df = worm_filter2.loc[SMDV_2]
SMDD_2_df = worm_filter2.loc[SMDD_2]

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/AVA_2_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
AVA_2_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/RME_2_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
RME_2_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/SMDD_2_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
SMDD_2_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/SMDV_2_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
SMDV_2_df.to_csv(file_path, index=True)

# %% [markdown]
# ## WORM3

# %%
co = []
for i in range(0, worm_filter3.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[12, :], worm_filter3.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
AVA_3 = np.where(co[:, 1] >= 0.7)

# %%
AVA_3

# %%
co = []
for i in range(0, worm_filter3.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[13, :], worm_filter3.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
RME_3 = np.where(co[:, 1] >= 0.7)

# %%
RME_3

# %%
co = []
for i in range(0, worm_filter3.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[14, :], worm_filter3.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
SMDD_3 = np.where(co[:, 1] >= 0.7)

# %%
SMDD_3

# %%
co = []
for i in range(0, worm_filter3.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[15, :], worm_filter3.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
SMDV_3 = np.where(co[:, 1] >= 0.7)

# %%
SMDV_3

# %%
#move worm1 global idx to a new column, and give it standard index
worm_filter3

# Step 1: Extract the first column and save it
global_cell_ids = worm_filter3.index

# Step 2: Drop the first column from the original position
worm_filter3 = worm_filter3.reset_index(drop=True)

# Step 3: Append it to the end of the DataFrame
worm_filter3['Global Cell IDs'] = global_cell_ids

# %%
AVA_3_df = worm_filter3.loc[AVA_3]
RME_3_df = worm_filter3.loc[RME_3]
SMDV_3_df = worm_filter3.loc[SMDV_3]
SMDD_3_df = worm_filter3.loc[SMDD_3]

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/AVA_3_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
AVA_3_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/RME_3_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
RME_3_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/SMDD_3_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
SMDD_3_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/SMDV_3_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
SMDV_3_df.to_csv(file_path, index=True)

# %% [markdown]
# ## WORM4

# %%
co = []
for i in range(0, worm_filter4.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[16, :], worm_filter4.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
AVA_4 = np.where(co[:, 1] >= 0.7)

# %%
AVA_4

# %%
co = []
for i in range(0, worm_filter4.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[17, :], worm_filter4.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
RME_4 = np.where(co[:, 1] >= 0.7)

# %%
RME_4

# %%
co = []
for i in range(0, worm_filter4.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[18, :], worm_filter4.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
SMDV_4 = np.where(co[:, 1] >= 0.7)

# %%
SMDV_4

# %%
co = []
for i in range(0, worm_filter4.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[19, :], worm_filter4.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
SMDD_4 = np.where(co[:, 1] >= 0.7)

# %%
SMDD_4

# %%
#move worm1 global idx to a new column, and give it standard index
worm_filter4

# Step 1: Extract the first column and save it
global_cell_ids = worm_filter4.index

# Step 2: Drop the first column from the original position
worm_filter4 = worm_filter4.reset_index(drop=True)

# Step 3: Append it to the end of the DataFrame
worm_filter4['Global Cell IDs'] = global_cell_ids

# %%
AVA_4_df = worm_filter4.loc[AVA_4]
RME_4_df = worm_filter4.loc[RME_4]
SMDV_4_df = worm_filter4.loc[SMDV_4]
SMDD_4_df = worm_filter4.loc[SMDD_4]

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/AVA_4_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
AVA_4_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/RME_4_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
RME_4_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/SMDV_4_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
SMDV_4_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/SMDD_4_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
SMDD_4_df.to_csv(file_path, index=True)

# %% [markdown]
# ## Worm 5

# %%
co = []
for i in range(0, worm_filter5.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[20, :], worm_filter5.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
AVA_5 = np.where(co[:, 1] >= 0.7)

# %%
co = []
for i in range(0, worm_filter5.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[21, :], worm_filter5.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
RME_5 = np.where(co[:, 1] >= 0.7)

# %%
co = []
for i in range(0, worm_filter5.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[22, :], worm_filter5.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
SMDV_5 = np.where(co[:, 1] >= 0.7)

# %%
co = []
for i in range(0, worm_filter5.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[23, :], worm_filter5.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
SMDD_5 = np.where(co[:, 1] >= 0.7)

# %%
#move worm1 global idx to a new column, and give it standard index
worm_filter5

# Step 1: Extract the first column and save it
global_cell_ids = worm_filter5.index

# Step 2: Drop the first column from the original position
worm_filter5 = worm_filter5.reset_index(drop=True)

# Step 3: Append it to the end of the DataFrame
worm_filter5['Global Cell IDs'] = global_cell_ids

# %%
AVA_5_df = worm_filter5.loc[AVA_5]
RME_5_df = worm_filter5.loc[RME_5]
SMDV_5_df = worm_filter5.loc[SMDV_5]
SMDD_5_df = worm_filter5.loc[SMDD_5]

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/AVA_5_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
AVA_5_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/RME_5_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
RME_5_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/SMDV_5_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
SMDV_5_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/SMDD_5_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
SMDD_5_df.to_csv(file_path, index=True)

# %% [markdown]
# ## Worm 6

# %%
co = []
for i in range(0, worm_filter6.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[24, :], worm_filter6.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
AVA_6 = np.where(co[:, 1] >= 0.7)

# %%
co = []
for i in range(0, worm_filter6.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[25, :], worm_filter6.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
RME_6 = np.where(co[:, 1] >= 0.7)

# %%
co = []
for i in range(0, worm_filter6.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[26, :], worm_filter6.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
SMDV_6 = np.where(co[:, 1] >= 0.7)

# %%
co = []
for i in range(0, worm_filter6.shape[0]):  # Start from the first row
    # Calculate Pearson correlation coefficient between the first row and the ith row
    corr, _ = pearsonr(yanno_full_df.iloc[27, :], worm_filter6.iloc[i, : -2])
    co.append((i, corr))

# %%
co = np.array(co)
SMDD_6 = np.where(co[:, 1] >= 0.7)

# %%
#move worm1 global idx to a new column, and give it standard index
worm_filter6

# Step 1: Extract the first column and save it
global_cell_ids = worm_filter6.index

# Step 2: Drop the first column from the original position
worm_filter6 = worm_filter6.reset_index(drop=True)

# Step 3: Append it to the end of the DataFrame
worm_filter6['Global Cell IDs'] = global_cell_ids

# %%
AVA_6_df = worm_filter6.loc[AVA_6]
RME_6_df = worm_filter6.loc[RME_6]
SMDV_6_df = worm_filter6.loc[SMDV_6]
SMDD_6_df = worm_filter6.loc[SMDD_6]

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/AVA_6_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
AVA_6_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/RME_6_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
RME_6_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/SMDV_6_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
SMDV_6_df.to_csv(file_path, index=True)

# %%
file_path = '/Users/iuliarusu/Documents/Sharpee/Clustering/clustered_bacterial_stim/SMDD_6_df.csv'  # Change the path as needed

# Save DataFrame to CSV, save index as seperate column
SMDD_6_df.to_csv(file_path, index=True)
